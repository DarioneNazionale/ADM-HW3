# %% [markdown]
# ## Question 2

# %% [markdown]
# #### just libraries

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import os
import csv
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Dario\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Dario\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %% [markdown]
# ### Function to preprocess
# remove punctuation, stop words and Stemming

# %%
def preprocess(s):
    
    #Remove punctuation and lower all characters
    words = nltk.word_tokenize(s)
    words = [word.lower() for word in words if word.isalnum()]
    
    #Remove stop words
    stop_words = set(stopwords.words('english'))
    words = [i for i in words if i not in stop_words]
    
    #Stemming
    stemmer = PorterStemmer()
    words = [stemmer.stem(word) for word in words]
    
    return words

# %% [markdown]
# ### working on all the files

# %%
preprocessed_intro_list = []
preprocessed_plot_list = []


fileNumber = 0 #starting from file 0
while os.path.exists("MoviesTSV\\article_" + str(fileNumber) + ".tsv"): #Iterating for each file 
    with open('MoviesTSV\\article_' + str(fileNumber) + '.tsv', encoding = 'utf8') as tsvfile:
        
        reader = csv.reader(tsvfile, delimiter='\t')
        row = next(reader)
        
        plot = row[1]
        intro = row[2]
        
        preprocessed_intro = preprocess(intro)
        preprocessed_plot = preprocess(plot)
            
            
        
        preprocessed_intro_list.append(preprocessed_intro)
        preprocessed_plot_list.append(preprocessed_plot)
        
        fileNumber += 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-489e4a18a7af> in <module>
#       4
#       5 fileNumber = 0 #starting from file 0
# ----> 6 while os.path.exists("MoviesTSV\\article_" + str(fileNumber) + ".tsv"): #Iterating for each file
#       7     with open('MoviesTSV\\article_' + str(fileNumber) + '.tsv', encoding = 'utf8') as tsvfile:
#       8
#
# NameError: name 'os' is not defined

# %%
len(preprocessed_intro_list)

# %%
len(preprocessed_plot_list)
# Out:
# 10000
